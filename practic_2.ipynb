# %% [markdown]
# <a href="https://colab.research.google.com/github/SergeevaAI/02-Practic/blob/main/practic_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Отчёт практика 2. Выполнила Сергеева Анастасия Игоревна АДЭУ-211
# 1. Job movies
#  ![image.png](data:image/png;base64,...)
# 2. Job filter_movies
#  ![image.png](data:image/png;base64,...)
#  ![image.png](data:image/png;base64,...)
# 3. Job write_movies
#  ![image.png](data:image/png;base64,...)
#  ![image.png](data:image/png;base64,...)
